# %% [markdown]
# #Idiomatic Python

# %%
from IPython.display import Image
Image('http://imgs.xkcd.com/comics/goto.png')

# %% [markdown]
# ##A few constant truths...
#
# ###1.  You almost never need to index

# %%
coordinates = (100, 335)

x, y = coordinates
